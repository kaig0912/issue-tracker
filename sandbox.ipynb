# %%
from sqlite3 import connect

# %%
connection = connect("issue_tracker.db")

# %%
einkaufswagen = connection.execute("""

create table if not exists issue (
    issue_id integer primary key,
    name text,
    priority text,
    deadline datetime,
    is_done boolean,
    description text               
);

""")

connection.commit()

connection.commit()

# %%
einkaufswagen = connection.execute("""

insert into issue (name, description, deadline, is_done) values
('Einkaufen gehen', 'Kaufe Milch, Eier und Brot', '2024-06-30 18:00:00', 0)
																	  
""")


connection.commit()

# %%
einkaufswagen = connection.execute("""

select * from issue;
																	  
""")


einkaufswagen.fetchall()
# Out:
# [(1,
#   'Einkaufen gehen',
#   None,
#   '2024-06-30 18:00:00',
#   None,
#   'Kaufe Milch, Eier und Brot'),
#  (2,
#   'Blumen kaufen',
#   None,
#   '2024-07-01 12:00:00',
#   None,
#   'Kaufe Rosen und Tulpen'),
#  (3,
#   'Blumen kaufen',
#   None,
#   '2024-07-01 12:00:00',
#   0,
#   'Kaufe Rosen und Tulpen'),
#  (4,
#   'Einkaufen gehen',
#   None,
#   '2024-06-30 18:00:00',
#   None,
#   'Kaufe Milch, Eier und Brot')]

# %%
def add_issue(name, description, deadline):
    connection = connect("issue_tracker.db")
    sql = f"insert into issue (name, description, deadline, is_done) values ('{name}', '{description}', '{deadline}', 0);"                                                  
    einkaufswagen = connection.execute(sql)
    connection.commit()
    connection.close()

# %%
add_issue('Blumen kaufen', 'Kaufe Rosen und Tulpen', '2024-07-01 12:00:00')

# %%
def get_issues():
    connection = connect("issue_tracker.db")
    sql = "select * from issue where is_done = 0;"
    einkaufswagen = connection.execute(sql)
    data = einkaufswagen.fetchall()
    connection.close()
    return data

# %%
get_issues()
# Out:
# [(5,
#   'Einkaufen gehen',
#   None,
#   '2024-06-30 18:00:00',
#   0,
#   'Kaufe Milch, Eier und Brot'),
#  (6,
#   'Einkaufen gehen',
#   None,
#   '2024-06-30 18:00:00',
#   0,
#   'Kaufe Milch, Eier und Brot')]

# %%
def set_issue_done(issue_id):
    connection = connect("issue_tracker.db")
    sql = f"update issue set is_done = 1 where issue_id = {issue_id};"
    cursor = connection.execute(sql)
    connection.commit()
    connection.close()

# %%
set_issue_done(3)
